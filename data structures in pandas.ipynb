# %%
import pandas as pd

# %%
s1 = pd.Series([90,77,99,76,84])
type(s1)
# Out:
# pandas.core.series.Series

# %%
print(s1)
# Out:
# 0    90
# 1    77
# 2    99
# 3    76
# 4    84
# dtype: int64

# %%
s2 = pd.Series([67,89,76,99,97],index = ["Harry","Sehgal","Tomar","Justin","Kokila"])
print(s2)
# Out:
# Harry     67
# Sehgal    89
# Tomar     76
# Justin    99
# Kokila    97
# dtype: int64

# %%
s2["Kokila"]
s2["Justin"]
# Out:
# np.int64(99)

# %%
data = { "name": ["Harry","James","Coles"],
         "age":[30,34,33],
         "city":["Bangalore","Vellore","Dhanbad"]
       }

# %%
d1 = pd.DataFrame(data)
d1
# Out:
#     name  age       city
# 0  Harry   30  Bangalore
# 1  James   34    Vellore
# 2  Coles   33    Dhanbad

# %%
d1.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
d1.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')
