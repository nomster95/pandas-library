# %%
import pandas as pd

# %%
df = pd.read_excel("filter.xlsx")
df
# Out:
#     name school  gender  marks
# 0   Alex    SSS    Male     88
# 1    Sam    FRD    Male     96
# 2   Rose    GPS  Female     87
# 3  Ember    TOS  Female     86
# 4  Jason    PSP    Male     99

# %%
df.sort_values("marks")
# Out:
#     name school  gender  marks
# 3  Ember    TOS  Female     86
# 2   Rose    GPS  Female     87
# 0   Alex    SSS    Male     88
# 1    Sam    FRD    Male     96
# 4  Jason    PSP    Male     99

# %%
df2 = df.sort_values("marks",ascending = False).copy()

# %%
df2
# Out:
#     name school  gender  marks
# 4  Jason    PSP    Male     99
# 1    Sam    FRD    Male     96
# 0   Alex    SSS    Male     88
# 2   Rose    GPS  Female     87
# 3  Ember    TOS  Female     86

# %%
df2.reset_index()
# Out:
#    index   name school  gender  marks
# 0      4  Jason    PSP    Male     99
# 1      1    Sam    FRD    Male     96
# 2      0   Alex    SSS    Male     88
# 3      2   Rose    GPS  Female     87
# 4      3  Ember    TOS  Female     86

# %%
df2
# Out:
#     name school  gender  marks
# 4  Jason    PSP    Male     99
# 1    Sam    FRD    Male     96
# 0   Alex    SSS    Male     88
# 2   Rose    GPS  Female     87
# 3  Ember    TOS  Female     86

# %%
df2.reset_index(drop = True)
# Out:
#     name school  gender  marks
# 0  Jason    PSP    Male     99
# 1    Sam    FRD    Male     96
# 2   Alex    SSS    Male     88
# 3   Rose    GPS  Female     87
# 4  Ember    TOS  Female     86

# %%
df2.reset_index(drop = True,inplace = True)

# %%
df2
# Out:
#     name school  gender  marks
# 0  Jason    PSP    Male     99
# 1    Sam    FRD    Male     96
# 2   Alex    SSS    Male     88
# 3   Rose    GPS  Female     87
# 4  Ember    TOS  Female     86

# %%
df2["Rank"] = df2["marks"].rank(ascending = False)
df2
# Out:
#     name school  gender  marks  Rank
# 0  Jason    PSP    Male     99   1.0
# 1    Sam    FRD    Male     96   2.0
# 2   Alex    SSS    Male     88   3.0
# 3   Rose    GPS  Female     87   4.0
# 4  Ember    TOS  Female     86   5.0

# %%
df2 = df2[["marks","gender","name","school"]]
df2
# Out:
#    marks  gender   name school
# 0     99    Male  Jason    PSP
# 1     96    Male    Sam    FRD
# 2     88    Male   Alex    SSS
# 3     87  Female   Rose    GPS
# 4     86  Female  Ember    TOS
