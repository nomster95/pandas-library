# %%
import pandas as pd

# %%
df.isnull() #jaha bhi null waha true aayega
# Out:
#     Name  School   Marks
# 0  False    False  False
# 1  False    False  False
# 2  False    False  False
# 3  False    False  False
# 4  False    False  False

# %%
df.isnull().sum()
# Out:
# Name       0
# School     0
# Marks      0
# dtype: int64

# %%
df = pd.read_excel("exp.xlsx")
df
# Out:
#     name school  gender  marks
# 0   Alex    NaN    Male   88.0
# 1    Sam    FRD    Male   96.0
# 2   Rose    GPS     NaN   87.0
# 3  Ember    TOS  Female    NaN
# 4  Jason    PSP    Male   99.0

# %%
df.isnull()
# Out:
#     name  school  gender  marks
# 0  False    True   False  False
# 1  False   False   False  False
# 2  False   False    True  False
# 3  False   False   False   True
# 4  False   False   False  False

# %%
df.isnull().sum()
# Out:
# name      0
# school    1
# gender    1
# marks     1
# dtype: int64

# %%
df.dropna()
# Out:
#     name school gender  marks
# 1    Sam    FRD   Male   96.0
# 4  Jason    PSP   Male   99.0

# %%
df.dropna(axis=1)
# Out:
#     name
# 0   Alex
# 1    Sam
# 2   Rose
# 3  Ember
# 4  Jason

# %%
df.fillna(0)
# Out:
#     name school  gender  marks
# 0   Alex      0    Male   88.0
# 1    Sam    FRD    Male   96.0
# 2   Rose    GPS       0   87.0
# 3  Ember    TOS  Female    0.0
# 4  Jason    PSP    Male   99.0

# %%
df.ffill()
# Out:
#     name school  gender  marks
# 0   Alex    NaN    Male   88.0
# 1    Sam    FRD    Male   96.0
# 2   Rose    GPS    Male   87.0
# 3  Ember    TOS  Female   87.0
# 4  Jason    PSP    Male   99.0

# %%
df.bfill()
# Out:
#     name school  gender  marks
# 0   Alex    FRD    Male   88.0
# 1    Sam    FRD    Male   96.0
# 2   Rose    GPS  Female   87.0
# 3  Ember    TOS  Female   99.0
# 4  Jason    PSP    Male   99.0

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#     name school  gender  marks
# 0   Alex    NaN    Male   88.0
# 1    Sam    FRD    Male   96.0
# 2   Rose    GPS     NaN   87.0
# 3  Ember    TOS  Female    NaN
# 4  Jason    PSP    Male   99.0

# %%
df['name'].str.lower()
# Out:
# 0     alex
# 1      sam
# 2     rose
# 3    ember
# 4    jason
# Name: name, dtype: object

# %%
df['school'].str.contains('GPS',case=False)
# Out:
# 0      NaN
# 1    False
# 2     True
# 3    False
# 4    False
# Name: school, dtype: object

# %%
df['name'].str.split("@")
# Out:
# 0     [Alex]
# 1      [Sam]
# 2     [Rose]
# 3    [Ember]
# 4    [Jason]
# Name: name, dtype: object

# %%
type(df['name'].str.split("@")[0])
# Out:
# list

# %%
df
# Out:
#     name school  gender  marks
# 0   Alex    NaN    Male   88.0
# 1    Sam    FRD    Male   96.0
# 2   Rose    GPS     NaN   87.0
# 3  Ember    TOS  Female    NaN
# 4  Jason    PSP    Male   99.0

# %%
df
# Out:
#     name school  gender  marks
# 0   Alex    NaN    Male   88.0
# 1    Sam    FRD    Male   96.0
# 2   Rose    GPS     NaN   87.0
# 3  Ember    TOS  Female    NaN
# 4  Jason    PSP    Male   99.0

# %%
df["grade"] = df["marks"].apply(lambda x: "A" if x>90 else "B")
df
# Out:
#     name school  gender  marks grade
# 0   Alex    NaN    Male   88.0     B
# 1    Sam    FRD    Male   96.0     A
# 2   Rose    GPS     NaN   87.0     B
# 3  Ember    TOS  Female    NaN     B
# 4  Jason    PSP    Male   99.0     A

# %%
df["name"].replace({"Sam": "Sams" })
df
# Out:
#     name school  gender  marks grade
# 0   Alex    NaN    Male   88.0     B
# 1    Sam    FRD    Male   96.0     A
# 2   Rose    GPS     NaN   87.0     B
# 3  Ember    TOS  Female    NaN     B
# 4  Jason    PSP    Male   99.0     A
